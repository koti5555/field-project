# %% [markdown]
# <a href="https://colab.research.google.com/github/koti5555/field-project/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
Audio("/content/VOICE TO TEXT.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install SpeechRecognition pyttsx3 pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 53.6 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as st
from pydub import AudioSegment

# Corrected file path - removed the extra .mp3 extension
mp3_file = '/content/VOICE TO TEXT.mp3'
wav_file = '/content/VOICE TO TEXT.wav'

audio = AudioSegment.from_mp3(mp3_file)
audio.export("audio.wav", format="wav")
# Out:
# <_io.BufferedRandom name='audio.wav'>

# %%
r = st.Recognizer()
with st.AudioFile("audio.wav") as source:
    audio_data = r.record(source)
    try:
        text = r.recognize_google(audio_data)
        print("Text from audio:")
        print(text)
    except st.UnknownValueError:
        print("Speech Recognition could not understand audio")
    except st.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
# Out:
# Text from audio:
# it sounds like you're looking to make company meetings longer or perhaps more substantial is that correct if so there are a few strategies to ensure meetings feel productive even when they are extended one detailed agendas break the meeting into specific time blocks for each topic this ensures you cover everything without rushing use sections like updates problem solving discussions brainstorming and action items to incorporate time for questions and discussions on each topic this ensures more interaction and deeper exploration 3.00

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
if 'text' in locals() and text:
  pass

# %%
summary = summarizer(text, max_length=130, min_length=30, do_sample=False)
print("\nSummary:")
# Out:
# Your max_length is set to 130, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Summary:

# %%
print(summary[0]['summary_text'])
# Out:
#  There are a few strategies to ensure meetings feel productive even when they are extended one detailed agendas break the meeting into specific time blocks for each topic this ensures you cover everything without rushing use sections like updates problem solving discussions brainstorming and action items to incorporate time for questions and discussions .

# %%
if 'summary' in locals() and summary:
    summary_text = summary[0]['summary_text']
    with open('/content/summary.txt', 'w') as f:
        f.write(summary_text)
    print("\nSummary saved to /content/summary.txt")
# Out:
# Summary saved to /content/summary.txt

# %%
import smtplib
from email.mime.text import MIMEText

# %%
# cell ipython-input-38-91b27f3e7c2c
sender_email = "yalagalakoti65@gmail.com"
sender_password = "#Koti2004"
receiver_email = "231fa04111@gmail.com"
subject = "Meeting Summary"
# Use summary_text directly
body = summary_text

# %%
msg = MIMEText(body)
msg['Subject'] = subject
msg['From'] = sender_email
msg['To'] = receiver_email

# %%
try:
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.login(sender_email, sender_password)
    server.sendmail(sender_email, receiver_email, msg.as_string())
    server.quit()
    print("Email sent successfully!")
except Exception as e:
    print(f"Error sending email: {e}")
# Out:
# Error sending email: (534, b'5.7.9 Application-specific password required. For more information, go to\n5.7.9  https://support.google.com/mail/?p=InvalidSecondFactor 71dfb90a1353d-52dba940919sm11192600e0c.17 - gsmtp')
